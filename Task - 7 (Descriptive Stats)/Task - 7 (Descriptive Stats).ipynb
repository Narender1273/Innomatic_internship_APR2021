# %% [markdown]
# # MEAN
#
# $\huge \mu = \frac{\sum X_i}{N}$
#
# **where**
#
# $\large {X_i}$ = sum of each variables\
# $\large N$ = total number of variables
#
# For Example: $\large \mu$ = $\frac {sum \ of \ individual \ variables}{total \ number \ of \ variables}$ =  $\large \frac {1+2+3+4+5+6+7+8+9}{9}$
#
#
# # MEDIAN
#
# if $n$ is even - $\hspace{1pt}$   $\huge X[\frac{n}{2}]$
#
# if $n$ is odd - $\hspace{1pt}$    $\huge \frac{(\huge X[\frac{n-1}{2}]+X[\frac{n+1}{2}])}{2}$
#
#  * For Example:
#
# - Calculate Median for the following- 4, 17, 77, 25, 22, 23, 92, 82, 40, 24, 14, 12, 67, 23, 29
#
# When we put those numbers in the order we have:
#
# 4, 12, 14, 17, 22, 23, 23, 24, 25, 29, 40, 67, 77, 82, 92,
#
# There are fifteen numbers. Our middle is the eighth number:
#
# The median value of this set of numbers is 24.
#
# # MODE
#
# $\huge M_o = {\huge l} + \huge (\frac {f_1 - f_0} {2f_1 - f_0 - f_2})\hspace{2pt}h $
#
# **Where**\
# $l$ = lower limit of modal class \
# h = size of class interval \
# $f_1$ = frequency of modal class\
# $f_0$ = frequency of class preceding modal class\
# $f_2$ = frequency of class succeeding modal class
#
#  * Example: In the given set of data: 2, 4, 5, 5, 6, 7, the mode of the data set is 5 since it has appeared in the set twice.
#
# **Bimodal, Trimodal & Multimodal (More than one mode)**
#
# When there are two modes in a data set, then the set is called bimodal
# For example, The mode of Set A = {2,2,2,3,4,4,5,5,5} is 2 and 5, because both 2 and 5 is repeated three times in the given set.
#
# When there are three modes in a data set, then the set is called trimodal
# For example, the mode of set A = {2,2,2,3,4,4,5,5,5,7,8,8,8} is 2, 5 and 8
#
# When there are four or more modes in a data set, then the set is called multimodal.
#
#
# # VARIANCE
#
# **POPULATION VARIANCE**:$\hspace{10pt}$ $\huge \sigma^2  =\huge \frac {\sum\limits _{i=1}^{N}(x_i - \mu)^2}{N}$ $\hspace{20pt}$ **SAMPLE VARIANCE**: $\hspace{5pt}$  $\huge s^2 = \huge \frac {\sum\limits _{i=1}^{N}(x_i - \bar x)^2}{n-1}$
#
# *where* $\hspace{169pt}$ *where*\
# $\hspace{30pt}$$\sigma^2$ = population variance $\hspace{90pt}$ $s^2$ = value of i^{th} element\
# $\hspace{30pt}$$x_i$ = value of $i^{th}$ element $\hspace{90.2pt}$ $x_i$ = value of i^{th} element\
# $\hspace{30pt}$$\mu$ = population mean $\hspace{99.6pt}$ $\bar x$ = sample mean\
# $\hspace{30pt}$$N$ = population size $\hspace{104pt}$ $n$ = sample size
#
#
# **For Example:**
#
# Find the variance for the following set of data representing trees heights in feet: 3, 21, 98, 203, 17, 9
#
# Step 1: Add up the numbers in your given data set.
#
# 3 + 21 + 98 + 203 + 17 + 9 = 351
#
# Step 2: Square your answer:
#
# $351^2$ = 123201
#
# and divide by the number of items. We have 6 items in our example so:
#
# $\large \frac {123201}{6}$ = 20533.5
#
# Step 3: Take your set of original numbers from Step 1, and square them individually this time:
#
# $3^2 + 21^2 + 98^2 + 203^2 + 17^2 + 9^2$
#
# Add the squares together:
#
# 9 + 441 + 9604 + 41209 + 289 + 81 = 51,633
#
# Step 4: Subtract the amount in Step 2 from the amount in Step 3.
#
# 51633 – 20533.5 = 31,099.5
#
# Set this number aside for a moment.
#
# Step 5: Subtract 1 from the number of items in your data set.
#
# For our example:
#
# 6 – 1 = 5
#
# Step 6: Divide the number in Step 4 by the number in Step 5. This gives you the variance:
#
# $\large \frac {31099.5}{5}$ = 6219.9
#
# Step 7: Take the square root of your answer from Step 6. This gives you the standard deviation:
#
# $\sqrt6219.9$ = 78.86634
#
# The answer is ($\sigma^2$) = 78.86.
#
#
#
# # STANDARD DEVIATION
#
# $\huge \sigma$ = $\huge \sqrt\frac {\sum(x_i - \mu)^2}{N}$
#
#
# *where*\
# $\sigma$ = population standard deviation\
# $N$ = size of population\
# $x_i$ = each value of population\
# $\mu$ = population mean
#
# From the above examaple :
#
# just do the square root of variance - $\large \sigma$ = $\large \sqrt \sigma^2$ = $\large \sqrt 78.86$ = 8.88
#
# # CORRELATION FORMULA
#
# $\huge r_{xy}$ =  $\huge\frac {\sum(x_i - \bar x)(y_i - \bar y)}{\sqrt\sum(x_i - \bar x)^2 \sum(y_i - \bar y)^2}$
#
# *where*\
# $r_{xy}$ = the correlation coefficient of the linear relationship between the variables x and y\
# $x_i$ – the values of the x-variable in a sample\
# $x̅$ – the mean of the values of the x-variable\
# $y_i$ – the values of the y-variable in a sample\
# $\bar y$ – the mean of the values of the y-variable

# %% [markdown]
# ### NORMAL DISTRIBUTION:
#
# $\hspace{100pt}$ $\huge f(x) = \frac {1}{\sigma\sqrt 2\pi} \large e^\frac {-(x-\mu)^2}{2\sigma^2}$
#
# **where**
#
# $f(x)$ = probability\
# $x$ = value of variable\
# $\mu$ = mean\
# $\sigma$ = standard deviation\
# $\sigma^2$ = variance
#
# ![image.png](attachment:image.png)
# * mean $\pm$ 1 standard deviations are 68.2% of area
# * mean $\pm$ 2 standard deviations are 95.4% of area
# * mean $\pm$ 3 standard deviations are 99.8% of area
#
# ### FEATURES OF NORMAL DISTRIBUTION:
#
# The two main parameters of a (normal) distribution are the mean and standard deviation. The parameters determine the shape and probabilities of the distribution. The shape of the distribution changes as the parameter values change.
#
#
#
# 1. Mean:
# The mean is used by researchers as a measure of central tendency. It can be used to describe the distribution of variables measured as ratios or intervals. In a normal distribution graph, the mean defines the location of the peak, and most of the data points are clustered around the mean. Any changes made to the value of the mean move the curve either to the left or right along the X-axis.
#
#
#
# 2. Standard Deviation:
# The standard deviation measures the dispersion of the data points relative to the mean. It determines how far away from the mean the data points are positioned and represents the distance between the mean and the observations.
#
# On the graph, the standard deviation determines the width of the curve, and it tightens or expands the width of the distribution along the x-axis. Typically, a small standard deviation relative to the mean produces a steep curve, while a large standard deviation relative to the mean produces a flatter curve.
#
# ## Z-SCORE
#
# **Z-scores tell you how many standard deviations away from the mean each value lies.**
#
# $\huge Z = \frac {x-\mu}{\sigma}$
#
# **where**
#
# $x$ = individual value\
# $\mu$ = mean\
# $\sigma$ = standard deviation

# %% [markdown]
# ### Positively Skewed & Negatively Skewed Normal Distribution
#
# Skewness is the degree of distortion from the symmetrical bell curve or the normal distribution. It measures the lack of symmetry in data distribution.
# It differentiates extreme values in one versus the other tail. A symmetrical distribution will have a skewness of 0.
#
# Distributions can exhibit right (positive) skewness or left (negative) skewness to varying degrees. A normal distribution (bell curve) exhibits zero skewness.
#
# There are two types of Skewness: Positive and Negative:
#
# ![image.png](attachment:image.png)
#
# **Positive Skewness:** means when the tail on the right side of the distribution is longer or fatter. The mean and median will be greater than the mode.
#
# **Negative Skewness:** is when the tail of the left side of the distribution is longer or fatter than the tail on the right side. The mean and median will be less than the mode.
#
# The rule of thumb seems to be:
#  * If the skewness is between -0.5 and 0.5, the data are fairly symmetrical.
#  * If the skewness is between -1 and -0.5(negatively skewed) or between 0.5 and 1(positively skewed), the data are moderately skewed.
#  * If the skewness is less than -1(negatively skewed) or greater than 1(positively skewed), the data are highly skewed.
#
# ### Kurtosis
#
# **Kurtosis** is all about the tails of the distribution — not the peakedness or flatness. It is used to describe the extreme values in one versus the other tail. It is actually the measure of outliers present in the distribution.
#
# **High kurtosis** in a data set is an indicator that data has heavy tails or outliers. If there is a high kurtosis, then, we need to investigate why do we have so many outliers. It indicates a lot of things, maybe wrong data entry or other things. Investigate!
#
# **Low kurtosis** in a data set is an indicator that data has light tails or lack of outliers. If we get low kurtosis(too good to be true), then also we need to investigate and trim the dataset of unwanted results.
# ![image-2.png](attachment:image-2.png)
#
# **Mesokurtic**: This distribution has kurtosis statistic similar to that of the normal distribution. It means that the extreme values of the distribution are similar to that of a normal distribution characteristic. This definition is used so that the standard normal distribution has a kurtosis of three.
#
# **Leptokurtic (Kurtosis > 3)**: Distribution is longer, tails are fatter. Peak is higher and sharper than Mesokurtic, which means that data are heavy-tailed or profusion of outliers.
# Outliers stretch the horizontal axis of the histogram graph, which makes the bulk of the data appear in a narrow (“skinny”) vertical range, thereby giving the “skinniness” of a leptokurtic distribution.
#
# **Platykurtic: (Kurtosis < 3)**: Distribution is shorter, tails are thinner than the normal distribution. The peak is lower and broader than Mesokurtic, which means that data are light-tailed or lack of outliers.
# The reason for this is because the extreme values are less than that of the normal distribution.

# %% [markdown]
# ## Effect on Mean, Median and Mode due to Skewness
#
# ### mathematical formula for skewness is:
#
# $$\huge a_3 = \sum \frac{(x_i - \bar x)^3}{ns^3} $$
#
# if the distribution of data is skewed to the left, the mean is less than the median, which is often less than the mode. If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.
#
# ![image.png](attachment:image.png)
#
#  * In a perfectly symmetrical distribution, the mean and the median are the same.
#
#  * The greater the deviation from zero indicates a greater degree of skewness. If the skewness is negative then the distribution is skewed left. A positive measure of skewness indicates right skewness.
#
#
#  ![image-2.png](attachment:image-2.png)
#
#  * **data: 6,7,7,7,7,8,8,8,9,10**
#  * The mean is 6.3, the median is 6.5, and the mode is seven. Notice that the mean is less than the median, and they are both less than the mode. The mean and the median both reflect the skewing, but the mean reflects it more so.
#
# ![image-3.png](attachment:image-3.png)
#
#   * The mean is 7.7, the median is 7.5, and the mode is seven. Of the three statistics, the mean is the largest, while the mode is the smallest. Again, the mean reflects the skewing the most.

# %% [markdown]
# ## Q-Q PLOT
#
# **Q-Q Plot compares two probability distributions by plotting their quantiles against each other. If the two distributions which we are comparing are exactly equal then the points on the Q-Q plot will perfectly lie on a straight line y = x.**
#
# ![image.png](attachment:image.png)
#
#  * if u see the graph of a qq plot it shows normally distributed because most of the data lies on the line.
#
#  * If all the points plotted on the graph perfectly lies on a straight line then we can clearly say that this distribution is Normally distribution because it is evenly aligned with the standard normal variate which is the simple concept of Q-Q plot.
#
#
#
# ![image-2.png](attachment:image-2.png)
#
# * Q-Q plots are also used to find the Skewness (a measure of “asymmetry”) of a distribution. When we plot theoretical quantiles on the x-axis and the sample quantiles whose distribution we want to know on the y-axis then we see a very peculiar shape of a Normally distributed Q-Q plot for skewness. If the bottom end of the Q-Q plot deviates from the straight line but the upper end is not, then we can clearly say that the distribution has a longer tail to its left or simply it is left-skewed (or negatively skewed) but when we see the upper end of the Q-Q plot to deviate from the straight line and the lower and follows a straight line then the curve has a longer till to its right and it is right-skewed (or positively skewed).
#
# ![image-3.png](attachment:image-3.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## BOX COX
#
# $|$ **A power transform is a family of functions applied to create a monotonic transformation of data using power functions. It is a data transformation technique used to stabilize variance, make the data more normal distribution-like, improve the validity of measures of association (such as the Pearson correlation between variables), and for other data stabilization procedures.** $|$
#
# $\huge y_i^\lambda = \huge \frac {y_i^\lambda - 1}{\lambda}$
#
# where\
# $Y$ is the response variable\
# $\lambda$ is the transformation parameter.
# * Additionally, transforming our variables can improve the predictive power of our models because transformations can cut away white noise.
# * We choose the value of lambda that provides the best approximation for the normal distribution of our response variable.
# Before             |  After applying box cox
# :-------------------------:|:-------------------------:
# ![image-2.png](attachment:image-2.png) | ![image-3.png](attachment:image-3.png)

# %%
import pandas as pd

data = pd.read_csv('data.csv',',')

# %%
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
# MEAN

sum(data.Mthly_HH_Income)/len(data)
# Out:
# 41558.0

# %%
data.mean()
# Out:
# Mthly_HH_Income           41558.00
# Mthly_HH_Expense          18818.00
# No_of_Fly_Members             4.06
# Emi_or_Rent_Amt            3060.00
# Annual_HH_Income         490019.04
# No_of_Earning_Members         1.46
# dtype: float64

# %%
# MEDIAN

data['No_of_Fly_Members'].sort_values()[len(data['No_of_Fly_Members'])/2]
# Out:
# 4

# %%
data.median()
# Out:
# Mthly_HH_Income           35000.0
# Mthly_HH_Expense          15500.0
# No_of_Fly_Members             4.0
# Emi_or_Rent_Amt               0.0
# Annual_HH_Income         447420.0
# No_of_Earning_Members         1.0
# dtype: float64

# %%
# MODE

def mode(lst):
    freq= {}
    for num in lst:
        freq.setdefault(num,0)
        freq[num]+=1
    highfreq = max(freq.values())
    highfreqlst=[]
    for num, freqq in freq.items():
        if freqq == highfreq:
            highfreqlst.append(num)
    return highfreqlst

mode(data['No_of_Fly_Members'])
# Out:
# [4]

# %%
# MODE
data['Mthly_HH_Income'].mode()
# Out:
# 0    45000
# dtype: int64

# %%
# VARIANCE

sum((data.Mthly_HH_Income-sum(data.Mthly_HH_Income)/len(data.Mthly_HH_Income))**2)/len(data.Mthly_HH_Income)
# Out:
# 667478836.0

# %%
data.var()
# Out:
# Mthly_HH_Income          6.811009e+08
# Mthly_HH_Expense         1.461733e+08
# No_of_Fly_Members        2.302449e+00
# Emi_or_Rent_Amt          3.895551e+07
# Annual_HH_Income         1.024869e+11
# No_of_Earning_Members    5.391837e-01
# dtype: float64

# %%
# STANDARD DEVIATION

((sum((data.No_of_Fly_Members-sum(data.No_of_Fly_Members)/len(data.No_of_Fly_Members))**2))/len(data.No_of_Fly_Members))**0.5
# Out:
# 1.502131818450032

# %%
data.std()
# Out:
# Mthly_HH_Income           26097.908979
# Mthly_HH_Expense          12090.216824
# No_of_Fly_Members             1.517382
# Emi_or_Rent_Amt            6241.434948
# Annual_HH_Income         320135.792123
# No_of_Earning_Members         0.734291
# dtype: float64

# %%
data.corr()
# Out:
#                        Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  \
# Mthly_HH_Income               1.000000          0.649215           0.448317
# Mthly_HH_Expense              0.649215          1.000000           0.639702
# No_of_Fly_Members             0.448317          0.639702           1.000000
# Emi_or_Rent_Amt               0.036976          0.405280           0.085808
# Annual_HH_Income              0.970315          0.591222           0.430868
# No_of_Earning_Members         0.347883          0.311915           0.597482
#
#                        Emi_or_Rent_Amt  Annual_HH_Income  \
# Mthly_HH_Income               0.036976          0.970315
# Mthly_HH_Expense              0.405280          0.591222
# No_of_Fly_Members             0.085808          0.430868
# Emi_or_Rent_Amt               1.000000          0.002716
# Annual_HH_Income              0.002716          1.000000
# No_of_Earning_Members        -0.097431          0.296679
#
# ...

# %%
mu_normal = data['Mthly_HH_Income'].mean()

sigma_normal = data['Mthly_HH_Income'].std()

print(mu_normal,sigma_normal)
# Out:
# 41558.0 26097.908978713687

# %%
one_std_right = mu_normal + (1 * sigma_normal)

one_std_left = mu_normal - (1 * sigma_normal)

two_std_right = mu_normal + (2 * sigma_normal)

two_std_left = mu_normal - (2 * sigma_normal)

three_std_right = mu_normal + (3 * sigma_normal)

three_std_left = mu_normal - (3 * sigma_normal)

# %%
plt.figure(figsize=(20,10))
sns.set_style("darkgrid")
sns.distplot(data['Mthly_HH_Income'])

plt.axvline(mu_normal, color='coral', label='Mean')

plt.axvline(one_std_right, color='yellow', label='Mean + 1SD')
plt.axvline(one_std_left, color='yellow', label='Mean - 1SD')
plt.axvline(two_std_right, color='green', label='Mean + 2SD')
plt.axvline(two_std_left, color='green', label='Mean - 2SD')
plt.axvline(three_std_right, color='blue', label='Mean + 3SD')
plt.axvline(three_std_left, color='blue', label='Mean - 3SD')
plt.legend();
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
(data['Mthly_HH_Income'] < one_std_right).sum()
# Out:
# 42

# %%
((one_std_left < data['Mthly_HH_Income']) & (data['Mthly_HH_Income'] < one_std_right)).sum()
# Out:
# 35

# %%
((one_std_left < data['Mthly_HH_Income']) & (data['Mthly_HH_Income'] < one_std_right)).sum()/data['Mthly_HH_Income'].size
# Out:
# 0.7

# %%
((two_std_left < data['Mthly_HH_Income']) & (data['Mthly_HH_Income'] < two_std_right)).sum()/data['Mthly_HH_Income'].size
# Out:
# 0.92

# %%
((three_std_left < data['Mthly_HH_Income']) & (data['Mthly_HH_Income'] < three_std_right)).sum()/data['Mthly_HH_Income'].size
# Out:
# 1.0

# %%
data['Mthly_HH_Income'].skew()

# %%
data['Mthly_HH_Income'].kurt()
# Out:
# 0.11555007146606489

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(data, x='Mthly_HH_Income', kde= True)

# %%
sns.displot(data, x='Emi_or_Rent_Amt', kde= True)

# %%
data.dtypes
# Out:
# Mthly_HH_Income              int64
# Mthly_HH_Expense             int64
# No_of_Fly_Members            int64
# Emi_or_Rent_Amt              int64
# Annual_HH_Income             int64
# Highest_Qualified_Member    object
# No_of_Earning_Members        int64
# dtype: object

# %%
from scipy import stats

stats.zscore(data[['Mthly_HH_Income','Mthly_HH_Expense']])
# Out:
# array([[-1.41502358, -0.90385726],
#        [-1.37631732, -0.98740849],
#        [-1.22149227, -1.19628658],
#        [-1.22149227, -1.40516467],
#        [-1.12472661, -0.56965232],
#        [-1.06666721, -0.90385726],
#        [-1.02796095, -0.23544738],
#        [-0.91184216,  0.09875756],
#        [-0.87313589, -0.82030602],
#        [-0.83442963, -0.82030602],
#        [-0.83442963, -0.06834491],
#        [-0.7570171 ,  0.51651373],
#        [-0.70282833, -1.15451096],
#        [-0.67960458, -0.69497917],
#        [-0.67960458, -0.73675479],
#        [-0.64089831, -0.54458695],
#        [-0.64089831,  0.09875756],
#        [-0.64089831, -0.73675479],
#        [-0.48607326, -1.02082899],
#        [-0.44736699, -0.48610108],
#        [-0.42801386,  0.51651373],
#        [-0.36995447, -0.31899861],
#        [-0.29254194,  0.01520632],
#        [-0.29254194,  0.51651373],
#        [-0.25383568, -0.56965232],
#        [-0.25383568,  0.51651373],
#        [-0.09901062, -0.90385726],
# ...

# %%
data_boxcox=stats.boxcox(data['Mthly_HH_Income'])

sns.displot(data_boxcox, kde=True)
# Out:
# C:\Users\ironm\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
data_boxcox
# Out:
# (array([ 40.31831648,  42.79683339,  50.5170921 ,  50.5170921 ,
#          54.28331821,  56.29587859,  57.55538753,  61.01339013,
#          62.0761407 ,  63.10059552,  63.10059552,  65.04699726,
#          66.33720359,  66.87370106,  66.87370106,  67.74745911,
#          67.74745911,  67.74745911,  71.01695067,  71.78461975,
#          72.16178108,  73.26802005,  74.68814484,  74.68814484,
#          75.37645286,  75.37645286,  78.0000836 ,  78.62643549,
#          79.84712626,  80.44232498,  81.60438084,  81.60438084,
#          81.60438084,  81.60438084,  82.17194858,  82.73098204,
#          84.35985154,  84.62465737,  86.92943718,  89.3410009 ,
#          89.3410009 ,  91.61630242,  93.77269407,  97.7826036 ,
#          99.65741298, 101.45686676, 104.19629334, 104.85663515,
#         104.85663515, 104.85663515]),
#  0.3031376789702236)

# %%
data
# Out:
#     Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0              5000          0.705591                  3             2000
# 1              6000          0.825738                  2             3000
# 2             10000          1.682330                  2                0
# 3             10000          0.779578                  1                0
# 4             12500          0.670950                  2             3000
# 5             14000          2.050797                  2                0
# 6             15000          0.576925                  3            35000
# 7             18000          0.439305                  5             8000
# 8             19000          0.957200                  2                0
# 9             20000          0.968054                  4                0
# 10            20000         -0.099342                  4             8000
# 11            22000          0.934868                  6            12000
# ...

# %%
# QQ plot

import pylab

stats.probplot(data['Mthly_HH_Expense'],dist="norm", plot=pylab)
pylab.show()

# %%
## QQ PLOT

data['Mthly_HH_Expense']=stats.loggamma.rvs(c=2.5, size=50)
stats.probplot(data['Mthly_HH_Expense'],dist=stats.loggamma, sparams=(2.5,), plot=pylab)
pylab.grid()

# %%
# QQ plot
import statsmodels.api as sm

sm.qqplot(data.Mthly_HH_Expense)
plt.grid()
